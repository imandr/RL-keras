# %% [markdown]
# Gamma = 0.8
#
# Model:
# ```python
#     inp = Input((inp_width,))
#     dense1 = Dense(25, activation="tanh", name="dense1")(inp)
#     dense2 = Dense(50, activation="softplus", name="dense2")(dense1)
#     dense3 = Dense(20, activation="softplus", name="dense3")(dense2)
#     out = Dense(out_width, activation="linear", name="out_linear")(dense3)
#     model = Model(inp, out)
# ```
# 2692 parameters
#
# 50 episodes/test run

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np

# %%
def smooth3s(x):
    if len(x) <= 2:
        return x
    y = np.empty_like(x)
    y[0], y[-1] = x[0], x[-1]
    for j in xrange(1,len(x)-1):
        y[j] = np.median(x[j-1:j+2])
    z = np.empty_like(y)
    z[0], z[-1] = (2*y[0]+y[1])/3, (2*y[-1]+y[-2])/3
    z[1:-1] = (y[1:-1] + y[:-2] + y[2:])/3
    return z

def smooth353(x):
    if len(x) <= 2:
        return x

    y3 = np.empty_like(x)
    y3[0], y3[-1] = x[0], x[-1]
    for j in xrange(1,len(x)-1):
        y3[j] = np.median(x[j-1:j+2])
        
    if len(y3) >= 5:
        y5 = np.empty_like(y3)
        y5[:2] = y3[:2]
        y5[-2:] = y3[-2:]
        for j in xrange(2,len(y3)-2):
            y5[j] = np.median(y3[j-2:j+3])
        y3[0], y3[-1] = y5[0], y5[-1]
        for j in xrange(1,len(x)-1):
            y3[j] = np.median(y5[j-1:j+2])

    return y3

def smooth353s(x):
    if len(x) < 3:
        return x
    
    x353 = smooth353(x)
    s = np.empty_like(x353)
    s[0], s[-1] = (2*x353[0]+x353[1])/3, (2*x353[-1]+x353[-2])/3
    s[1:-1] = (x353[1:-1] + x353[:-2] + x353[2:])/3
    
    return s
    

x= np.random.random((30,))
print x
plt.plot(x)
plt.plot(smooth353s(x))
plt.plot(smooth3s(x))
# Out:
# [0.33818391 0.62818039 0.79132405 0.90680269 0.35641825 0.41711364
#  0.7524129  0.22354651 0.93172851 0.92328066 0.10458551 0.41276297
#  0.13891923 0.12129108 0.09074944 0.64289714 0.79827302 0.76956474
#  0.64579369 0.71061692 0.3779703  0.27460758 0.17816103 0.82241985
#  0.57246038 0.3306657  0.52295971 0.98553377 0.64621619 0.22250304]

# %%
smooth(np.array([1.1,1.,-1.]))
# Out:
# array([ 1.06666667,  0.36666667, -0.33333333])

# %% [markdown]
# Differential
#
# V-selective memory
#
# 7/21/2018

# %%
df=pd.read_csv("run_log.csv")
x=df["episodes"].values
y=df["reward_per_episode"].values
plt.plot(x,y)
plt.plot(x,smooth(y))

# %% [markdown]
# Differential
#
# non-selective memory
#
# 7/21/2018

# %%
df=pd.read_csv("run_log.csv")
x=df["episodes"].values
y=df["reward_per_episode"].values
plt.plot(x,y)
plt.plot(x,smooth(y))

# %% [markdown]
# Dual QNet
#
# soft_update=0.01
#
# V-selective memory
#
# 7/21/2018

# %%
df=pd.read_csv("run_log.csv")
x=df["episodes"].values
y=df["reward_per_episode"].values
plt.plot(x,y)
plt.plot(x,smooth(y))

# %% [markdown]
# Dual QNet
#
# soft_update=0.01
#
# non-selective memory
#
# 7/21/2018

# %%
df=pd.read_csv("run_log.csv")
x=df["episodes"].values
y=df["reward_per_episode"].values
plt.plot(x,y)
plt.plot(x,smooth(y))

# %% [markdown]
# Dual QNet
#
# soft_update=0.5
#
# non-selective memory
#
# 7/21/2018

# %%
df=pd.read_csv("run_log.csv")
x=df["episodes"].values
y=df["reward_per_episode"].values
plt.plot(x,y)
plt.plot(x,smooth(y))

# %% [markdown]
# Dual QNet
#
# soft_update=0.99
#
# non-selective memory
#
# 7/21/2018

# %%
df=pd.read_csv("run_log.csv")
x=df["episodes"].values
y=df["reward_per_episode"].values
plt.plot(x,y)
plt.plot(x,smooth(y))

# %% [markdown]
# Dual QNet
#
# soft_update=0.9999
#
# non-selective memory
#
# 7/21/2018

# %%
df=pd.read_csv("run_log.csv")
x=df["episodes"].values
y=df["reward_per_episode"].values
plt.plot(x,y)
plt.plot(x,smooth(y))

# %% [markdown]
# Gamma = 0.99

# %% [markdown]
# Differential
# non-selective memory

# %%
df=pd.read_csv("run_log.csv")
x=df["episodes"].values
y=df["reward_per_episode"].values
plt.plot(x,y)
plt.plot(x,smooth(y))

# %% [markdown]
# Differential
# V-selective memory

# %%
df=pd.read_csv("run_log.csv")
x=df["episodes"].values
y=df["reward_per_episode"].values
plt.plot(x,y)
plt.plot(x,smooth(y))

# %% [markdown]
# Evolution
# memory transfer = 0.5, 1/6
# gamma = 0.99
# v-selection
# 3 agents with random independent start

# %%
df=pd.read_csv("run_log.csv")
x=df["episodes"].values[:100]
y=df["reward_per_episode"].values[:100]
plt.plot(x,y)
plt.plot(x,smooth(y))

# %% [markdown]
# Evolution
# memory transfer = 0.5, 1/6
# gamma = 0.99
# v-selection
# 3 agents with same start

# %%
df=pd.read_csv("run_log.csv")
x=df["episodes"].values
y=df["reward_per_episode"].values
plt.plot(x,y)
plt.plot(x,smooth(y))

# %%
df=pd.read_csv("run_log.csv")
x=df["episodes"].values
y=df["reward_per_episode"].values
loss=df["loss_ma"].values

plt.subplot(121)
plt.plot(x,y, ls="None", marker=".")
plt.plot(x,smooth(y))

plt.subplot(122)
plt.plot(x, loss, ls="None", marker=".")
plt.plot(x, smooth(loss))

# %%
df=pd.read_csv("run_log.csv")
x=df["episodes"].values[:200]
y=df["reward_per_episode"].values[:200]
loss=df["loss_ma"].values[:200]

plt.subplot(121)
plt.plot(x,y, ls="None", marker=".")
plt.plot(x,smooth353s(y))

plt.subplot(122)
plt.plot(x, loss, ls="None", marker=".")
plt.plot(x, smooth353s(loss))

# %%
df=pd.read_csv("run_log.csv")
x=df["episodes"].values[:200]
y=df["reward_per_episode"].values[:200]
loss=df["loss_ma"].values[:200]

plt.subplot(121)
plt.plot(x,y, ls="None", marker=".")
plt.plot(x,smooth353s(y))

plt.subplot(122)
plt.plot(x, loss, ls="None", marker=".")
plt.plot(x, smooth353s(loss))
